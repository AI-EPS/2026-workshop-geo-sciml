# %% [markdown]
# # Julia Machine Learning demo
#
# ## My first neural network
#
# Before running this notebook, start Julia in the project folder with `julia --project=.` and add the required packages in Pkg mode with:
#
# ```julia
# add CSV DataFrames Lux Optimisers Zygote Statistics Random
# ```
#
# `Printf` is part of Julia's standard library, so it does not need to be added.
#
# In this demo, we train a small neural network that predicts a sauna enjoyment score from three inputs:
#
# - sauna temperature
# - outside temperature
# - minutes since the coffee was brewed
#
# The goal is to learn the relationship from example data and then use the trained model to score a few Finnish sauna scenarios.

# %% [markdown]
# ## Step 1: Load and prepare the data
#
# We already have example sauna data in a text file, so the first job is to load it into Julia and turn it into numeric arrays the network can use.

# %%
using CSV
using DataFrames
using Lux
using Random
using Optimisers
using Zygote
using Statistics
using Printf

sauna_path = joinpath(pwd(), "data", "sauna_log.txt")
sauna_log = CSV.read(sauna_path, DataFrame)

# Convert the table into a numeric matrix.
# Rows 1:3 will be inputs and row 4 will be the target score.
feature_table = Matrix(sauna_log[:, [:sauna_temp, :outside_temp, :coffee_min, :score]])
data = Float32.(permutedims(feature_table))

input_data_raw = data[1:3, :]
target_scores = data[4:4, :]

# We normalize the inputs because the three features live on very different
# scales. This makes training more stable and helps gradient-based updates.
feature_mean = mean(input_data_raw, dims = 2)
feature_std = std(input_data_raw, dims = 2)
input_data = (input_data_raw .- feature_mean) ./ feature_std

# Split to train and test (80/20).
# The model learns only from the training split. The test split is kept aside
# and used only at the end to measure performance on unseen data.
rng = Xoshiro(123)
n_train = Int(round(0.8 * size(input_data, 2)))
shuffled_indices = randperm(rng, size(input_data, 2))

X_train = input_data[:, shuffled_indices[1:n_train]]
Y_train = target_scores[:, shuffled_indices[1:n_train]]
X_test = input_data[:, shuffled_indices[n_train + 1:end]]
Y_test = target_scores[:, shuffled_indices[n_train + 1:end]]

@printf "Train: %d  Test: %d\n" size(X_train, 2) size(X_test, 2)
# Out:
# Train: 160  Test: 40

# %% [markdown]
# ## Step 2: Build the model
#
# Now we define a very small neural network. It takes 3 inputs, transforms them through a hidden layer, and returns 1 predicted enjoyment score.
#
# ```
# Inputs              Hidden layer               Output
#
# sauna temp    o ----\
#                   o --\
# outside temp  o -----)--- o  o  o  o  o  o  o  o ----> o   predicted score
#                   o --/
# coffee age    o ----/
#
# 3 features        Dense(3 => 8, tanh)      Dense(8 => 1, sigmoid)
# ```
#
# The final sigmoid keeps the prediction in the 0 to 1 range.

# %%
model = Chain(
    Dense(3 => 8, tanh),
    Dense(8 => 1, sigmoid)
)

# Initialize model parameters and state
parameters, model_state = Lux.setup(rng, model)
# Out:
# ((layer_1 = (weight = Float32[-0.71197426 0.5440084 -0.9027876; -0.62075335 -0.5090574 1.4643831; … ; 0.7166022 -0.17811993 0.5175801; -1.5047655 -0.24505515 1.5166628], bias = Float32[0.23182774, -0.18704338, 0.17974052, 0.15094592, -0.023374384, 0.47140634, -0.18232994, 0.08013492]), layer_2 = (weight = Float32[-0.48614922 0.6079607 … -0.5020537 -0.45970005], bias = Float32[0.24544002])), (layer_1 = NamedTuple(), layer_2 = NamedTuple()))

# %% [markdown]
# ## Step 3: Train the network
#
# We now define the loss and the training function. The training function takes the network, its parameters, and the training data, then repeatedly updates the parameters to reduce prediction error.
#
# - Epochs = how many times we loop over the training data
# - Learning rate = how large each parameter update should be

# %%
# This function takes a batch of inputs and target scores, runs the network,
# and returns the mean squared error. Training will try to make this smaller.
function mse_loss(model, parameters, model_state, batch)
    x, y_true = batch
    y_pred, new_model_state = model(x, parameters, model_state)
    loss = mean((y_pred .- y_true) .^ 2)
    return loss, new_model_state, ()
end

function train_model(model, parameters, model_state, train_batch; epochs = 500, lr = 0.01f0)
    train_state = Training.TrainState(model, parameters, model_state, Adam(lr))
    for epoch in 1:epochs
        _, loss, _, train_state = Training.single_train_step!(AutoZygote(), mse_loss, train_batch, train_state)
        @printf "Epoch %4d  Training loss = %.6f\n" epoch loss
    end
    return train_state
end

train_state = train_model(model, parameters, model_state, (X_train, Y_train))
# Out:
# Epoch    1  Training loss = 0.105149
# Epoch    2  Training loss = 0.103422
# Epoch    3  Training loss = 0.102009
# Epoch    4  Training loss = 0.100871
# Epoch    5  Training loss = 0.099936
# Epoch    6  Training loss = 0.099146
# Epoch    7  Training loss = 0.098451
# Epoch    8  Training loss = 0.097809
# Epoch    9  Training loss = 0.097179
# Epoch   10  Training loss = 0.096531
# Epoch   11  Training loss = 0.095855
# Epoch   12  Training loss = 0.095156
# Epoch   13  Training loss = 0.094442
# Epoch   14  Training loss = 0.093724
# Epoch   15  Training loss = 0.093007
# Epoch   16  Training loss = 0.092288
# Epoch   17  Training loss = 0.091562
# Epoch   18  Training loss = 0.090823
# Epoch   19  Training loss = 0.090062
# Epoch   20  Training loss = 0.089277
# Epoch   21  Training loss = 0.088464
# Epoch   22  Training loss = 0.087621
# Epoch   23  Training loss = 0.086749
# Epoch   24  Training loss = 0.085846
# Epoch   25  Training loss = 0.084914
# Epoch   26  Training loss = 0.083954
# Epoch   27  Training loss = 0.082967
# Epoch   28  Training loss = 0.081955
# Epoch   29  Training loss = 0.080917
# Epoch   30  Training loss = 0.079851
# Epoch   31  Training loss = 0.078754
# Epoch   32  Training loss = 0.077623
# Epoch   33  Training loss = 0.076456
# Epoch   34  Training loss = 0.075253
# Epoch   35  Training loss = 0.074012
# Epoch   36  Training loss = 0.072735
# Epoch   37  Training loss = 0.071422
# Epoch   38  Training loss = 0.070074
# Epoch   39  Training loss = 0.068694
# Epoch   40  Training loss = 0.067282
# Epoch   41  Training loss = 0.065840
# Epoch   42  Training loss = 0.064370
# Epoch   43  Training loss = 0.062871
# Epoch   44  Training loss = 0.061345
# Epoch   45  Training loss = 0.059794
# Epoch   46  Training loss = 0.058220
# Epoch   47  Training loss = 0.056626
# Epoch   48  Training loss = 0.055013
# Epoch   49  Training loss = 0.053386
# Epoch   50  Training loss = 0.051748
# Epoch   51  Training loss = 0.050102
# Epoch   52  Training loss = 0.048453
# Epoch   53  Training loss = 0.046803
# Epoch   54  Training loss = 0.045156
# Epoch   55  Training loss = 0.043516
# Epoch   56  Training loss = 0.041888
# Epoch   57  Training loss = 0.040274
# Epoch   58  Training loss = 0.038679
# Epoch   59  Training loss = 0.037107
# Epoch   60  Training loss = 0.035562
# Epoch   61  Training loss = 0.034048
# Epoch   62  Training loss = 0.032569
# Epoch   63  Training loss = 0.031127
# Epoch   64  Training loss = 0.029725
# Epoch   65  Training loss = 0.028367
# Epoch   66  Training loss = 0.027053
# Epoch   67  Training loss = 0.025788
# Epoch   68  Training loss = 0.024572
# Epoch   69  Training loss = 0.023407
# Epoch   70  Training loss = 0.022294
# Epoch   71  Training loss = 0.021233
# Epoch   72  Training loss = 0.020226
# Epoch   73  Training loss = 0.019272
# Epoch   74  Training loss = 0.018370
# Epoch   75  Training loss = 0.017520
# Epoch   76  Training loss = 0.016719
# Epoch   77  Training loss = 0.015967
# Epoch   78  Training loss = 0.015262
# Epoch   79  Training loss = 0.014601
# Epoch   80  Training loss = 0.013983
# Epoch   81  Training loss = 0.013406
# Epoch   82  Training loss = 0.012867
# Epoch   83  Training loss = 0.012365
# Epoch   84  Training loss = 0.011897
# Epoch   85  Training loss = 0.011462
# Epoch   86  Training loss = 0.011057
# Epoch   87  Training loss = 0.010680
# Epoch   88  Training loss = 0.010331
# Epoch   89  Training loss = 0.010006
# Epoch   90  Training loss = 0.009704
# Epoch   91  Training loss = 0.009424
# Epoch   92  Training loss = 0.009165
# Epoch   93  Training loss = 0.008924
# Epoch   94  Training loss = 0.008701
# Epoch   95  Training loss = 0.008494
# Epoch   96  Training loss = 0.008303
# Epoch   97  Training loss = 0.008125
# Epoch   98  Training loss = 0.007961
# Epoch   99  Training loss = 0.007809
# Epoch  100  Training loss = 0.007668
# Epoch  101  Training loss = 0.007537
# Epoch  102  Training loss = 0.007417
# Epoch  103  Training loss = 0.007305
# Epoch  104  Training loss = 0.007201
# Epoch  105  Training loss = 0.007106
# Epoch  106  Training loss = 0.007017
# Epoch  107  Training loss = 0.006935
# Epoch  108  Training loss = 0.006859
# Epoch  109  Training loss = 0.006789
# Epoch  110  Training loss = 0.006723
# Epoch  111  Training loss = 0.006663
# Epoch  112  Training loss = 0.006606
# Epoch  113  Training loss = 0.006554
# Epoch  114  Training loss = 0.006505
# Epoch  115  Training loss = 0.006460
# Epoch  116  Training loss = 0.006418
# Epoch  117  Training loss = 0.006378
# Epoch  118  Training loss = 0.006342
# Epoch  119  Training loss = 0.006307
# Epoch  120  Training loss = 0.006274
# Epoch  121  Training loss = 0.006244
# Epoch  122  Training loss = 0.006215
# Epoch  123  Training loss = 0.006188
# Epoch  124  Training loss = 0.006162
# Epoch  125  Training loss = 0.006138
# Epoch  126  Training loss = 0.006115
# Epoch  127  Training loss = 0.006093
# Epoch  128  Training loss = 0.006072
# Epoch  129  Training loss = 0.006052
# Epoch  130  Training loss = 0.006033
# Epoch  131  Training loss = 0.006014
# Epoch  132  Training loss = 0.005997
# Epoch  133  Training loss = 0.005980
# Epoch  134  Training loss = 0.005964
# Epoch  135  Training loss = 0.005948
# Epoch  136  Training loss = 0.005933
# Epoch  137  Training loss = 0.005919
# Epoch  138  Training loss = 0.005905
# Epoch  139  Training loss = 0.005892
# Epoch  140  Training loss = 0.005879
# Epoch  141  Training loss = 0.005866
# Epoch  142  Training loss = 0.005854
# Epoch  143  Training loss = 0.005842
# Epoch  144  Training loss = 0.005831
# Epoch  145  Training loss = 0.005820
# Epoch  146  Training loss = 0.005809
# Epoch  147  Training loss = 0.005799
# Epoch  148  Training loss = 0.005789
# Epoch  149  Training loss = 0.005779
# Epoch  150  Training loss = 0.005770
# Epoch  151  Training loss = 0.005760
# Epoch  152  Training loss = 0.005751
# Epoch  153  Training loss = 0.005742
# Epoch  154  Training loss = 0.005733
# Epoch  155  Training loss = 0.005725
# Epoch  156  Training loss = 0.005716
# Epoch  157  Training loss = 0.005708
# Epoch  158  Training loss = 0.005700
# Epoch  159  Training loss = 0.005692
# Epoch  160  Training loss = 0.005684
# Epoch  161  Training loss = 0.005676
# Epoch  162  Training loss = 0.005669
# Epoch  163  Training loss = 0.005661
# Epoch  164  Training loss = 0.005654
# Epoch  165  Training loss = 0.005647
# Epoch  166  Training loss = 0.005639
# Epoch  167  Training loss = 0.005632
# Epoch  168  Training loss = 0.005625
# Epoch  169  Training loss = 0.005618
# Epoch  170  Training loss = 0.005612
# Epoch  171  Training loss = 0.005605
# Epoch  172  Training loss = 0.005598
# Epoch  173  Training loss = 0.005591
# Epoch  174  Training loss = 0.005585
# Epoch  175  Training loss = 0.005578
# Epoch  176  Training loss = 0.005572
# Epoch  177  Training loss = 0.005566
# Epoch  178  Training loss = 0.005559
# Epoch  179  Training loss = 0.005553
# Epoch  180  Training loss = 0.005547
# Epoch  181  Training loss = 0.005541
# Epoch  182  Training loss = 0.005535
# Epoch  183  Training loss = 0.005529
# Epoch  184  Training loss = 0.005523
# Epoch  185  Training loss = 0.005517
# Epoch  186  Training loss = 0.005511
# Epoch  187  Training loss = 0.005505
# Epoch  188  Training loss = 0.005499
# Epoch  189  Training loss = 0.005493
# Epoch  190  Training loss = 0.005488
# Epoch  191  Training loss = 0.005482
# Epoch  192  Training loss = 0.005476
# Epoch  193  Training loss = 0.005471
# Epoch  194  Training loss = 0.005465
# Epoch  195  Training loss = 0.005460
# Epoch  196  Training loss = 0.005454
# Epoch  197  Training loss = 0.005449
# Epoch  198  Training loss = 0.005444
# Epoch  199  Training loss = 0.005438
# Epoch  200  Training loss = 0.005433
# Epoch  201  Training loss = 0.005428
# Epoch  202  Training loss = 0.005423
# Epoch  203  Training loss = 0.005417
# Epoch  204  Training loss = 0.005412
# Epoch  205  Training loss = 0.005407
# Epoch  206  Training loss = 0.005402
# Epoch  207  Training loss = 0.005397
# Epoch  208  Training loss = 0.005392
# Epoch  209  Training loss = 0.005387
# Epoch  210  Training loss = 0.005382
# Epoch  211  Training loss = 0.005377
# Epoch  212  Training loss = 0.005373
# Epoch  213  Training loss = 0.005368
# Epoch  214  Training loss = 0.005363
# Epoch  215  Training loss = 0.005358
# Epoch  216  Training loss = 0.005354
# Epoch  217  Training loss = 0.005349
# Epoch  218  Training loss = 0.005344
# Epoch  219  Training loss = 0.005340
# Epoch  220  Training loss = 0.005335
# Epoch  221  Training loss = 0.005331
# Epoch  222  Training loss = 0.005326
# Epoch  223  Training loss = 0.005322
# Epoch  224  Training loss = 0.005317
# Epoch  225  Training loss = 0.005313
# Epoch  226  Training loss = 0.005309
# Epoch  227  Training loss = 0.005304
# Epoch  228  Training loss = 0.005300
# Epoch  229  Training loss = 0.005296
# Epoch  230  Training loss = 0.005292
# Epoch  231  Training loss = 0.005288
# Epoch  232  Training loss = 0.005284
# Epoch  233  Training loss = 0.005280
# Epoch  234  Training loss = 0.005276
# Epoch  235  Training loss = 0.005272
# Epoch  236  Training loss = 0.005268
# Epoch  237  Training loss = 0.005264
# Epoch  238  Training loss = 0.005260
# Epoch  239  Training loss = 0.005256
# Epoch  240  Training loss = 0.005252
# Epoch  241  Training loss = 0.005248
# Epoch  242  Training loss = 0.005245
# Epoch  243  Training loss = 0.005241
# Epoch  244  Training loss = 0.005237
# Epoch  245  Training loss = 0.005234
# Epoch  246  Training loss = 0.005230
# Epoch  247  Training loss = 0.005226
# Epoch  248  Training loss = 0.005223
# Epoch  249  Training loss = 0.005219
# Epoch  250  Training loss = 0.005216
# Epoch  251  Training loss = 0.005212
# Epoch  252  Training loss = 0.005209
# Epoch  253  Training loss = 0.005206
# Epoch  254  Training loss = 0.005202
# Epoch  255  Training loss = 0.005199
# Epoch  256  Training loss = 0.005196
# Epoch  257  Training loss = 0.005193
# Epoch  258  Training loss = 0.005189
# Epoch  259  Training loss = 0.005186
# Epoch  260  Training loss = 0.005183
# Epoch  261  Training loss = 0.005180
# Epoch  262  Training loss = 0.005177
# Epoch  263  Training loss = 0.005174
# Epoch  264  Training loss = 0.005171
# Epoch  265  Training loss = 0.005168
# Epoch  266  Training loss = 0.005165
# Epoch  267  Training loss = 0.005162
# Epoch  268  Training loss = 0.005159
# Epoch  269  Training loss = 0.005156
# Epoch  270  Training loss = 0.005153
# Epoch  271  Training loss = 0.005150
# Epoch  272  Training loss = 0.005147
# Epoch  273  Training loss = 0.005144
# Epoch  274  Training loss = 0.005141
# Epoch  275  Training loss = 0.005139
# Epoch  276  Training loss = 0.005136
# Epoch  277  Training loss = 0.005133
# Epoch  278  Training loss = 0.005130
# Epoch  279  Training loss = 0.005128
# Epoch  280  Training loss = 0.005125
# Epoch  281  Training loss = 0.005122
# Epoch  282  Training loss = 0.005119
# Epoch  283  Training loss = 0.005117
# Epoch  284  Training loss = 0.005114
# Epoch  285  Training loss = 0.005112
# Epoch  286  Training loss = 0.005109
# Epoch  287  Training loss = 0.005106
# Epoch  288  Training loss = 0.005104
# Epoch  289  Training loss = 0.005101
# Epoch  290  Training loss = 0.005099
# Epoch  291  Training loss = 0.005096
# Epoch  292  Training loss = 0.005093
# Epoch  293  Training loss = 0.005091
# Epoch  294  Training loss = 0.005088
# Epoch  295  Training loss = 0.005086
# Epoch  296  Training loss = 0.005083
# Epoch  297  Training loss = 0.005081
# Epoch  298  Training loss = 0.005078
# Epoch  299  Training loss = 0.005076
# Epoch  300  Training loss = 0.005073
# Epoch  301  Training loss = 0.005071
# Epoch  302  Training loss = 0.005069
# Epoch  303  Training loss = 0.005066
# Epoch  304  Training loss = 0.005064
# Epoch  305  Training loss = 0.005061
# Epoch  306  Training loss = 0.005059
# Epoch  307  Training loss = 0.005056
# Epoch  308  Training loss = 0.005054
# Epoch  309  Training loss = 0.005051
# Epoch  310  Training loss = 0.005049
# Epoch  311  Training loss = 0.005046
# Epoch  312  Training loss = 0.005044
# Epoch  313  Training loss = 0.005041
# Epoch  314  Training loss = 0.005039
# Epoch  315  Training loss = 0.005036
# Epoch  316  Training loss = 0.005034
# Epoch  317  Training loss = 0.005032
# Epoch  318  Training loss = 0.005029
# Epoch  319  Training loss = 0.005027
# Epoch  320  Training loss = 0.005024
# Epoch  321  Training loss = 0.005022
# Epoch  322  Training loss = 0.005019
# Epoch  323  Training loss = 0.005017
# Epoch  324  Training loss = 0.005014
# Epoch  325  Training loss = 0.005011
# Epoch  326  Training loss = 0.005009
# Epoch  327  Training loss = 0.005006
# Epoch  328  Training loss = 0.005004
# Epoch  329  Training loss = 0.005001
# Epoch  330  Training loss = 0.004999
# Epoch  331  Training loss = 0.004996
# Epoch  332  Training loss = 0.004993
# Epoch  333  Training loss = 0.004991
# Epoch  334  Training loss = 0.004988
# Epoch  335  Training loss = 0.004985
# Epoch  336  Training loss = 0.004983
# Epoch  337  Training loss = 0.004980
# Epoch  338  Training loss = 0.004977
# Epoch  339  Training loss = 0.004975
# Epoch  340  Training loss = 0.004972
# Epoch  341  Training loss = 0.004969
# Epoch  342  Training loss = 0.004966
# Epoch  343  Training loss = 0.004964
# Epoch  344  Training loss = 0.004961
# Epoch  345  Training loss = 0.004958
# Epoch  346  Training loss = 0.004955
# Epoch  347  Training loss = 0.004952
# Epoch  348  Training loss = 0.004949
# Epoch  349  Training loss = 0.004946
# Epoch  350  Training loss = 0.004943
# Epoch  351  Training loss = 0.004940
# Epoch  352  Training loss = 0.004937
# Epoch  353  Training loss = 0.004934
# Epoch  354  Training loss = 0.004931
# Epoch  355  Training loss = 0.004928
# Epoch  356  Training loss = 0.004925
# Epoch  357  Training loss = 0.004922
# Epoch  358  Training loss = 0.004919
# Epoch  359  Training loss = 0.004916
# Epoch  360  Training loss = 0.004912
# Epoch  361  Training loss = 0.004909
# Epoch  362  Training loss = 0.004906
# Epoch  363  Training loss = 0.004903
# Epoch  364  Training loss = 0.004899
# Epoch  365  Training loss = 0.004896
# Epoch  366  Training loss = 0.004893
# Epoch  367  Training loss = 0.004889
# Epoch  368  Training loss = 0.004886
# Epoch  369  Training loss = 0.004882
# Epoch  370  Training loss = 0.004879
# Epoch  371  Training loss = 0.004875
# Epoch  372  Training loss = 0.004872
# Epoch  373  Training loss = 0.004868
# Epoch  374  Training loss = 0.004865
# Epoch  375  Training loss = 0.004861
# Epoch  376  Training loss = 0.004857
# Epoch  377  Training loss = 0.004854
# Epoch  378  Training loss = 0.004850
# Epoch  379  Training loss = 0.004846
# Epoch  380  Training loss = 0.004842
# Epoch  381  Training loss = 0.004839
# Epoch  382  Training loss = 0.004835
# Epoch  383  Training loss = 0.004831
# Epoch  384  Training loss = 0.004827
# Epoch  385  Training loss = 0.004823
# Epoch  386  Training loss = 0.004819
# Epoch  387  Training loss = 0.004815
# Epoch  388  Training loss = 0.004811
# Epoch  389  Training loss = 0.004808
# Epoch  390  Training loss = 0.004804
# Epoch  391  Training loss = 0.004800
# Epoch  392  Training loss = 0.004796
# Epoch  393  Training loss = 0.004791
# Epoch  394  Training loss = 0.004787
# Epoch  395  Training loss = 0.004783
# Epoch  396  Training loss = 0.004779
# Epoch  397  Training loss = 0.004775
# Epoch  398  Training loss = 0.004771
# Epoch  399  Training loss = 0.004767
# Epoch  400  Training loss = 0.004763
# Epoch  401  Training loss = 0.004759
# Epoch  402  Training loss = 0.004754
# Epoch  403  Training loss = 0.004750
# Epoch  404  Training loss = 0.004746
# Epoch  405  Training loss = 0.004742
# Epoch  406  Training loss = 0.004738
# Epoch  407  Training loss = 0.004734
# Epoch  408  Training loss = 0.004729
# Epoch  409  Training loss = 0.004725
# Epoch  410  Training loss = 0.004721
# Epoch  411  Training loss = 0.004717
# Epoch  412  Training loss = 0.004712
# Epoch  413  Training loss = 0.004708
# Epoch  414  Training loss = 0.004704
# Epoch  415  Training loss = 0.004700
# Epoch  416  Training loss = 0.004695
# Epoch  417  Training loss = 0.004691
# Epoch  418  Training loss = 0.004687
# Epoch  419  Training loss = 0.004683
# Epoch  420  Training loss = 0.004678
# Epoch  421  Training loss = 0.004674
# Epoch  422  Training loss = 0.004670
# Epoch  423  Training loss = 0.004665
# Epoch  424  Training loss = 0.004661
# Epoch  425  Training loss = 0.004657
# Epoch  426  Training loss = 0.004652
# Epoch  427  Training loss = 0.004648
# Epoch  428  Training loss = 0.004644
# Epoch  429  Training loss = 0.004639
# Epoch  430  Training loss = 0.004635
# Epoch  431  Training loss = 0.004631
# Epoch  432  Training loss = 0.004626
# Epoch  433  Training loss = 0.004622
# Epoch  434  Training loss = 0.004618
# Epoch  435  Training loss = 0.004613
# Epoch  436  Training loss = 0.004609
# Epoch  437  Training loss = 0.004605
# Epoch  438  Training loss = 0.004600
# Epoch  439  Training loss = 0.004596
# Epoch  440  Training loss = 0.004592
# Epoch  441  Training loss = 0.004587
# Epoch  442  Training loss = 0.004583
# Epoch  443  Training loss = 0.004579
# Epoch  444  Training loss = 0.004574
# Epoch  445  Training loss = 0.004570
# Epoch  446  Training loss = 0.004566
# Epoch  447  Training loss = 0.004561
# Epoch  448  Training loss = 0.004557
# Epoch  449  Training loss = 0.004553
# Epoch  450  Training loss = 0.004548
# Epoch  451  Training loss = 0.004544
# Epoch  452  Training loss = 0.004540
# Epoch  453  Training loss = 0.004536
# Epoch  454  Training loss = 0.004532
# Epoch  455  Training loss = 0.004527
# Epoch  456  Training loss = 0.004523
# Epoch  457  Training loss = 0.004519
# Epoch  458  Training loss = 0.004515
# Epoch  459  Training loss = 0.004511
# Epoch  460  Training loss = 0.004507
# Epoch  461  Training loss = 0.004503
# Epoch  462  Training loss = 0.004499
# Epoch  463  Training loss = 0.004495
# Epoch  464  Training loss = 0.004491
# Epoch  465  Training loss = 0.004488
# Epoch  466  Training loss = 0.004484
# Epoch  467  Training loss = 0.004480
# Epoch  468  Training loss = 0.004476
# Epoch  469  Training loss = 0.004473
# Epoch  470  Training loss = 0.004469
# Epoch  471  Training loss = 0.004466
# Epoch  472  Training loss = 0.004462
# Epoch  473  Training loss = 0.004459
# Epoch  474  Training loss = 0.004455
# Epoch  475  Training loss = 0.004452
# Epoch  476  Training loss = 0.004449
# Epoch  477  Training loss = 0.004446
# Epoch  478  Training loss = 0.004442
# Epoch  479  Training loss = 0.004439
# Epoch  480  Training loss = 0.004436
# Epoch  481  Training loss = 0.004433
# Epoch  482  Training loss = 0.004430
# Epoch  483  Training loss = 0.004427
# Epoch  484  Training loss = 0.004424
# Epoch  485  Training loss = 0.004421
# Epoch  486  Training loss = 0.004419
# Epoch  487  Training loss = 0.004416
# Epoch  488  Training loss = 0.004413
# Epoch  489  Training loss = 0.004410
# Epoch  490  Training loss = 0.004408
# Epoch  491  Training loss = 0.004405
# Epoch  492  Training loss = 0.004403
# Epoch  493  Training loss = 0.004400
# Epoch  494  Training loss = 0.004398
# Epoch  495  Training loss = 0.004395
# Epoch  496  Training loss = 0.004393
# Epoch  497  Training loss = 0.004390
# Epoch  498  Training loss = 0.004388
# Epoch  499  Training loss = 0.004386
# Epoch  500  Training loss = 0.004383
# TrainState(
#     Chain(
#         layer_1 = Dense(3 => 8, tanh),            # 32 parameters
#         layer_2 = Dense(8 => 1, σ),               # 9 parameters
#     ),
#     number of parameters: 41
#     number of states: 0
#     optimizer: Adam(eta=0.01, beta=(0.9, 0.999), epsilon=1.0e-8)
#     step: 500
# )

# %% [markdown]
# ## Step 4: Evaluate on the test split
#
# After training, run the model on the held-out data to get a final test error that summarizes how well it predicts unseen examples.

# %%
Y_pred_test, _ = model(X_test, train_state.parameters, train_state.states)
test_mse = mean((Y_pred_test .- Y_test) .^ 2)
test_mae = mean(abs.(Y_pred_test .- Y_test))

@printf "Test MSE: %.6f  Test MAE: %.4f\n" test_mse test_mae
# Out:
# Test MSE: 0.006914  Test MAE: 0.0638

# %% [markdown]
# ## Step 5: Predict a few sauna scenarios
#
# Finally, try a few hand-picked sauna situations and see what score the trained network gives to each one.

# %%
scenarios = [
    (sauna = 80, outside = -20, coffee = 10),
    (sauna = 65, outside = 5, coffee = 100),
    (sauna = 95, outside = -25, coffee = 30)
]

# This function takes one scenario, normalizes it the same way as the training
# data, feeds it through the trained network, and returns one predicted score.
function predict_score(s, model, parameters, model_state, feature_mean, feature_std)
    x = Float32.([
        (s.sauna - feature_mean[1]) / feature_std[1],
        (s.outside - feature_mean[2]) / feature_std[2],
        (s.coffee - feature_mean[3]) / feature_std[3]
    ])
    pred, _ = model(reshape(x, 3, 1), parameters, model_state)
    return pred[1]
end

for scenario in scenarios
    predicted_score = predict_score(scenario, model, train_state.parameters, train_state.states, feature_mean, feature_std)
    @printf "Scenario: sauna=%dC outside=%dC coffee=%dmin\n" scenario.sauna scenario.outside scenario.coffee
    @printf "Predicted score: %.2f\n\n" predicted_score
end
# Out:
# Scenario: sauna=80C outside=-20C coffee=10min
# Predicted score: 0.98
#
# Scenario: sauna=65C outside=5C coffee=100min
# Predicted score: 0.10
#
# Scenario: sauna=95C outside=-25C coffee=30min
# Predicted score: 0.40
